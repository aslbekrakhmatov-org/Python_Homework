# %% [markdown]
# ##### task1

# %%
import pandas as pd
df_titanic = pd.read_excel("../data/titanic.xlsx")
def check_survived(x):
    return x[x["Survived"]==1].copy() 
df_titanic.pipe(check_survived)
def fill_AgeNaNs(x):
    x.loc[:, "Age"] = x["Age"].fillna(x["Age"].mean())
    return x
df_titanic.pipe(fill_AgeNaNs)
def Fare_per_age(x):
    x.loc[:, "Fare_per_Age"]=x['Fare']/x['Age']
    return x
df_titanic = (
    df_titanic.pipe(check_survived)
    .pipe(fill_AgeNaNs)
    .pipe(Fare_per_age)
)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##### task2

# %%
df_flights = pd.read_parquet("../data/flights")
def filter_by_delay(df):
    return df[pd.to_numeric(df["DepDelay"], errors="coerce")>30].copy()

def Delay_per_Hour(df):
    df.loc[:, "Delay_Per_Hour"]= pd.to_numeric(df["DepDelay"], errors="coerce")/pd.to_numeric(df["Duration"], errors="coerce")

df_flights=(
    df_flights.pipe(filter_by_delay)
    .pipe(Delay_per_Hour)
)
df_flights
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Aslbek Rakhmatov\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 10
# ...
